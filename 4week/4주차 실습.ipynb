# %% [markdown]
# # 머신러닝

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats

# %%
from sklearn.model_selection import train_test_split

df = pd.read_csv("C:/AI/5week/heart.csv", index_col=0)
df
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 63     1   3       145   233    1        0      150      0      2.3      0
# 37     1   2       130   250    0        1      187      0      3.5      0
# 41     0   1       130   204    0        0      172      0      1.4      2
# 56     1   1       120   236    0        1      178      0      0.8      2
# 57     0   0       120   354    0        1      163      1      0.6      2
# ..   ...  ..       ...   ...  ...      ...      ...    ...      ...    ...
# 57     0   0       140   241    0        1      123      1      0.2      1
# 45     1   3       110   264    0        1      132      0      1.2      1
# 68     1   0       144   193    1        1      141      0      3.4      1
# 57     1   0       130   131    0        1      115      1      1.2      1
# 57     0   1       130   236    0        0      174      0      0.0      1
#
#      ca  thal  target
# age
# 63    0     1       1
# 37    0     2       1
# 41    0     2       1
# 56    0     2       1
# 57    0     2       1
# ..   ..   ...     ...
# 57    0     3       0
# 45    0     3       0
# 68    2     3       0
# 57    1     3       0
# 57    1     2       0
#
# [303 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
X = df.drop('target',axis=1)
X.head()
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 63     1   3       145   233    1        0      150      0      2.3      0
# 37     1   2       130   250    0        1      187      0      3.5      0
# 41     0   1       130   204    0        0      172      0      1.4      2
# 56     1   1       120   236    0        1      178      0      0.8      2
# 57     0   0       120   354    0        1      163      1      0.6      2
#
#      ca  thal
# age
# 63    0     1
# 37    0     2
# 41    0     2
# 56    0     2
# 57    0     2

# %%
y = df['target']
y.head()
# Out:
# age
# 63    1
# 37    1
# 41    1
# 56    1
# 57    1
# Name: target, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X,
                                                  y,
                                                  test_size=0.2,
                                                  shuffle=True,
                                                  random_state=12)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (242, 12) (242,)
# (61, 12) (61,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)
ly_preds = model.predict(X_test)

print('평균제곱근오차', mean_squared_error(ly_preds, y_test))
# Out:
# 평균제곱근오차 0.1430474897181202

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))
# Out:
# 평균제곱근오차 0.21311475409836064

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 0.16337540983606558

# %%
from sklearn.svm import SVR

model = SVR(kernel='linear')
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 0.14292133248168995

# %% [markdown]
# # 딥러닝

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\chaes\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (3.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (3.9.1)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\chaes\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\chaes\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\chaes\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\chaes\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\chaes\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chaes\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chaes\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chaes\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chaes\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\chaes\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\chaes\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\chaes\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\chaes\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\chaes\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\chaes\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\chaes\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("C:/AI/5week/heart.csv", index_col=0)
df
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 63     1   3       145   233    1        0      150      0      2.3      0
# 37     1   2       130   250    0        1      187      0      3.5      0
# 41     0   1       130   204    0        0      172      0      1.4      2
# 56     1   1       120   236    0        1      178      0      0.8      2
# 57     0   0       120   354    0        1      163      1      0.6      2
# ..   ...  ..       ...   ...  ...      ...      ...    ...      ...    ...
# 57     0   0       140   241    0        1      123      1      0.2      1
# 45     1   3       110   264    0        1      132      0      1.2      1
# 68     1   0       144   193    1        1      141      0      3.4      1
# 57     1   0       130   131    0        1      115      1      1.2      1
# 57     0   1       130   236    0        0      174      0      0.0      1
#
#      ca  thal  target
# age
# 63    0     1       1
# 37    0     2       1
# 41    0     2       1
# 56    0     2       1
# 57    0     2       1
# ..   ..   ...     ...
# 57    0     3       0
# 45    0     3       0
# 68    2     3       0
# 57    1     3       0
# 57    1     2       0
#
# [303 rows x 13 columns]

# %%
# 레이블 갯수 확인 (숫자)
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
X=df.drop('target',axis=1)
X.head()
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 63     1   3       145   233    1        0      150      0      2.3      0
# 37     1   2       130   250    0        1      187      0      3.5      0
# 41     0   1       130   204    0        0      172      0      1.4      2
# 56     1   1       120   236    0        1      178      0      0.8      2
# 57     0   0       120   354    0        1      163      1      0.6      2
#
#      ca  thal
# age
# 63    0     1
# 37    0     2
# 41    0     2
# 56    0     2
# 57    0     2

# %%
y=df['target']
y.value_counts()
y.head()
# Out:
# age
# 63    1
# 37    1
# 41    1
# 56    1
# 57    1
# Name: target, dtype: int64

# %% [markdown]
# ## 원 핫 인코딩

# %%
Y = pd.get_dummies(y).values

# %% [markdown]
# ## 딥러닝 입력을 위해 Numpy로 변환

# %%
X = X.values

# %%
X
# Out:
# array([[  1.,   3., 145., ...,   0.,   0.,   1.],
#        [  1.,   2., 130., ...,   0.,   0.,   2.],
#        [  0.,   1., 130., ...,   2.,   0.,   2.],
#        ...,
#        [  1.,   0., 144., ...,   1.,   2.,   3.],
#        [  1.,   0., 130., ...,   1.,   1.,   3.],
#        [  0.,   1., 130., ...,   1.,   1.,   2.]])

# %%
Y
# Out:
# array([[False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
X_train.shape,X_test.shape, y_train.shape,y_test.shape
# Out:
# ((242, 12), (61, 12), (242, 2), (61, 2))

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense